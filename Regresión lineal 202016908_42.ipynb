# %% [markdown]
# Ejercicio Regresión Lineal

# %%
#Se importan las librerías necesarias
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
#Se genera la variable que llama al csv a través de pandas
reglin = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")

# %%
#Se visualiza un determinado número de filas en el archivo para comprobar si se cargó correctamente
reglin.head(17)
# Out:
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0           1    Male   27     Software Engineer             6.1
# 1           2    Male   28                Doctor             6.2
# 2           3    Male   28                Doctor             6.2
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# 5           6    Male   28     Software Engineer             5.9
# 6           7    Male   29               Teacher             6.3
# 7           8    Male   29                Doctor             7.8
# 8           9    Male   29                Doctor             7.8
# 9          10    Male   29                Doctor             7.8
# 10         11    Male   29                Doctor             6.1
# 11         12    Male   29                Doctor             7.8
# 12         13    Male   29                Doctor             6.1
# ...

# %%
#Se genera la gráfica de dispersión
reglin.plot.scatter(x="Quality of Sleep", y="Occupation")
plt.show()

# %%
#Se crea la variable de regresión que contiene el modelo
regresion = linear_model.LinearRegression()

# %%
#Se agregan los datos a un arreglo
Profesion = reglin["Occupation"].values.reshape((-1,1))

# %%
#Se crea el modelo

modelo = regresion.fit(CalidadS, reglin["Quality of Sleep"])

#Se imprime interseccion y pendiente

print("Interseccion (b)", modelo.intercept_)
print("Pendiente (m)", modelo.coef_)
# Out:
# Interseccion (b) -1.7763568394002505e-15
# Pendiente (m) [1.]

# %%
#Se indican las entradas por donde pasará la línea de regresión
entrada = [[5],[7],[9]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [5. 7. 9.]

# %%
#Se genera la gráfica de regresión lineal
reglin.plot.scatter(x="Quality of Sleep", y="Occupation", label= 'Calidad de sueño por profesión')
plt.scatter(entrada, predicciones, color='green')
plt.plot(entrada, predicciones, color='red', label='Línea de Regresión')
plt.xlabel('Quality of Sleep')
plt.ylabel('Occupation')
plt.legend()
plt.show()
