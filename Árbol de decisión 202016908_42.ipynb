# %% [markdown]
# Ejercicio arbol de decisión

# %%
#Se importan las librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree

# %%
#Se genera la variable que llama al csv a través de pandas
arbdec = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")

# %%
#Se visualiza un determinado número de filas en el archivo para comprobar si se cargó correctamente
arbdec.head(3)
# Out:
#    Person ID Gender  Age         Occupation  Sleep Duration  Quality of Sleep  \
# 0          1   Male   27  Software Engineer             6.1                 6
# 1          2   Male   28             Doctor             6.2                 6
# 2          3   Male   28             Doctor             6.2                 6
#
#    Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                       42             6   Overweight         126/83
# 1                       60             8       Normal         125/80
# 2                       60             8       Normal         125/80
#
#    Heart Rate  Daily Steps Sleep Disorder
# 0          77         4200           None
# 1          75        10000           None
# 2          75        10000           None

# %%
# Seleccionar las columnas relevantes (variables independientes) para el análisis
seleccion = ['Age','Sleep Duration','Quality of Sleep','Stress Level',]

# %%
# Crear rango de columnas (X) y variable objetivo (y)
X = reglog[seleccion]
y = reglog['Gender']

# %%
# Dividir los datos en conjuntos de entrenamiento(70%) y prueba(30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Crear y entrenar el modelo de árbol de decisión
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Calcular la precisión del modelo
y_pred = model.predict(X_test)
accuracy = (y_pred == y_test).mean()
print(f'Precisión del modelo: {accuracy * 100:.2f}%')
# Out:
# Precisión del modelo: 94.69%

# %%
# Crear y visualizar el árbol de decisión
plt.figure(figsize=(10, 10))
tree.plot_tree(model, feature_names=seleccion, class_names=[str(i) for i in range(1, 4)], filled=True, rounded=True)
plt.title("Clasificación de calidad de sueño (Árbol de Decisión)")
plt.show()
